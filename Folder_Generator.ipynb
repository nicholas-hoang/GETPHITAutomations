# %%
# Load Modules from requirements.txt
# %pip install -r requirements.txt

# Importing the necessary libraries
import os
import pandas as pd
import numpy as np
import shutil
import pathlib
import xlwings as xw

# Import glob, os, and load_workbook from openpyxl
import glob
from openpyxl import load_workbook
# Out:
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'
# Note: you may need to restart the kernel to use updated packages.

# %%
class BootCamp:

        def __init__ (self, file, evaluation):
                self.file = file
                self.evaluation = evaluation
        
        def load_data(self):
                student_registration = pd.read_excel(self.file)
                student_registration = student_registration.rename(columns={
                'Registration Date': 'Registration_Date',
                'First Name': 'First_Name',
                'Last Name': 'Last_Name'})
                
                student_registration.Registration_Date = student_registration.Registration_Date.dt.strftime('%m/%d/%Y')
     
                with open(self.evaluation, 'r') as f:
                        evaluation_form = pd.read_excel(f)
     
                return student_registration, evaluation_form
        

BootCamp = BootCamp('Bootcamp Applications UTEP 5-1-23.xlsx', 'Evaluation_Rubric.xlsx' )
df = BootCamp.load_data()[0]

# %% [markdown]
# #### Extract Student First Names and Last Names

# %%
def get_first_last_name(row):
   fullname = row.First_Name + " " + row.Last_Name
   return fullname

# %% [markdown]
# Check the Format of the Table

# %%
df
# Out:
#        Status Registration_Date  First_Name         Last_Name  \
# 0   Wait List        05/11/2022       Diana            Garcia
# 1   Wait List        05/12/2022      Daniel          Martinez
# 2   Wait List        05/24/2022      Jordan  Davidson-Frazier
# 3   Wait List        05/29/2022    Patricia          Martinez
# 4   Wait List        05/30/2022  Temiloluwa          Osinaike
# 5   Wait List        06/21/2022    Khadijah            Taylor
# 6   Wait List        06/22/2022      Justin           Mchorse
# 7   Wait List        06/23/2022        Iman             Matan
# 8   Wait List        06/23/2022   Gabrielle         Whitworth
# 9   Wait List        06/24/2022      Glenda          Martinez
# 10  Wait List        06/29/2022       Neira             Garza
# 11  Wait List        07/01/2022    LaQuisha            Parker
# 12  Wait List        07/01/2022     Camilla            Taylor
# 13  Wait List        07/01/2022   Christina             Green
# 14  Wait List        07/01/2022      Kyanee         Castaneda
# 15  Wait List        07/02/2022    Kaitlynn      De La Fuente
# 16  Wait List        07/02/2022     Kristal            Joiner
# 17  Wait List        07/04/2022       Reina      Shewakramani
# 18  Wait List        07/05/2022     Dayvion            Hunter
# 19  Wait List        07/05/2022     Brieana            Fields
#
#                           Email  \
# 0      diana.garcia18@utrgv.edu
# 1          danmar2702@gmail.com
# 2    jdavidsonfrazier@gmail.com
# 3    celestemtz2015@hotmail.com
# 4   oluwatoniosinaike@gmail.com
# 5              kataylor@htu.edu
# 6             jlmchorse@htu.edu
# 7          Imanmatan7@gmail.com
# 8           gwhit0617@gmail.com
# 9   glenda.martinez92@gmail.com
# 10      neira.garza01@utrgv.edu
# 11           mslqpolk@gmail.com
# 12              ctaylor@htu.edu
# 13  greenchristina730@gmail.com
# 14          Kyanee321@gmail.com
# 15         kndelafuente@htu.edu
# 16        kjoiner0127@gmail.com
# 17        reina@dusty.tamiu.edu
# 18           dayvionh@gmail.com
# 19  brieanafields2000@gmail.com
#
#              What school are you affiliated with?                full_name
# 0   University of Texas-Rio Grande Valley (UTRGV)             Diana Garcia
# 1   University of Texas-Rio Grande Valley (UTRGV)          Daniel Martinez
# 2                        Prairie View A&M (PVAMU)  Jordan Davidson-Frazier
# 3   University of Texas-Rio Grande Valley (UTRGV)        Patricia Martinez
# 4                        Prairie View A&M (PVAMU)      Temiloluwa Osinaike
# 5                          Huston-Tilloston (HTU)          Khadijah Taylor
# 6                          Huston-Tilloston (HTU)           Justin Mchorse
# 7                          Huston-Tilloston (HTU)               Iman Matan
# 8                          Huston-Tilloston (HTU)      Gabrielle Whitworth
# 9                          Huston-Tilloston (HTU)          Glenda Martinez
# 10  University of Texas-Rio Grande Valley (UTRGV)              Neira Garza
# 11                         Huston-Tilloston (HTU)          LaQuisha Parker
# 12                         Huston-Tilloston (HTU)           Camilla Taylor
# 13                         Huston-Tilloston (HTU)          Christina Green
# 14                         Huston-Tilloston (HTU)         Kyanee Castaneda
# 15                         Huston-Tilloston (HTU)    Kaitlynn De La Fuente
# 16                         Huston-Tilloston (HTU)           Kristal Joiner
# 17                Texas A&M International (TAMIU)       Reina Shewakramani
# 18                         Huston-Tilloston (HTU)           Dayvion Hunter
# 19                       Prairie View A&M (PVAMU)           Brieana Fields

# %% [markdown]
# ### Create Folders From Series of Full Name

# %%
""" get_existing_folders() function checks the current directory for existing folders and returns a list of the folders found.
"""

def get_existing_folders():
    num_of_docs = [directory for directory in os.listdir('.') if os.path.isdir(os.path.join(".", directory))]
    print(f'There are a total of {len(num_of_docs)} student folders in this directory.')
    return num_of_docs

get_existing_folders()

# %%
def create_new_folders():    
    count = 0 
    student_names = pd.Series(df.full_name)
    
    for student in student_names:
        os.mkdir(student.title()) # Create Student Folder
        count +=1
    
    print(f'A total of {count} student folders were generated.')

student_folders = create_new_folders()
# Out:
# A total of 20 student folders were generated.

# %%
""" fill_folders(evaluation_form): takes the evaluation form and places it in each student folder.
"""
def fill_folders(evaluation_form):  
    path = pathlib.Path('.')
# Put Evaluation Form In Student Folders 
    for item in path.iterdir():
        if item.is_dir():
            shutil.copy2(evaluation_form, item) # Place Form in Folder

fill_folders(BootCamp.load_data()[1])

# %%
""" rename_files() function renames the files in the student folders to the name of the folder.
"""

def rename_files():
    path = pathlib.Path('.')
    for folder in path.iterdir():
        if folder.is_dir():
            for file in folder.iterdir():
                if file.is_file():
                    new_file = folder.name + file.suffix
                    file.rename(path /folder.name/ new_file)

rename_files()

# %%
""" writeStudentNames() function writes the student names to the evaluation form."""

def writeStudentNames():

    # Get a list of files with extension .xlsx
    student_files = glob.glob('*.xlsx')

    # Iterate through each file in student_files
    for file in student_files:
        try:
            # Load Workbook in Binary Mode
            workbook = load_workbook(filename=file)

            # Define desired sheet names
            sheet = workbook['Evaluator 1']

            # Extract student name from filename
            student_name = os.path.splitext(file.name)[0]

            # Define desired cell value 
            sheet['B3'] = student_name

            # Save and close the workbook
            workbook.save(filename=file)
            workbook.close()

        except Exception as e:
            print(f"Error writing student name to {file}: {e}")

writeStudentNames()

# %%
def main():
    df = BootCamp.load_data()[0]
    get_existing_folders()
    df['full_name'] = df.apply(get_first_last_name, axis = 1)
    create_new_folders()
    fill_folders(BootCamp.load_data()[1])
    rename_files()
    writeStudentNames()

if __name__ == "__main__":
    main()

# %%
#TODO: Create a function that will write the registration date to the evaluation form.
